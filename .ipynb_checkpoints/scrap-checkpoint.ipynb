# %%
import numpy as np
import pandas as pd

# %%
from shm import newmann_beta

# %%
# %matplotlib inline

# %%
number_of_time_points = 100

# %%
m = 1
c = 1.5
k = 200

# %%
dt = 1/200

# %%
f = (np.random.rand(number_of_time_points) - 0.5) * 2.0

# %%
df = newmann_beta(m, c, k, dt, f, number_of_time_points)

# %%
df.plot()
